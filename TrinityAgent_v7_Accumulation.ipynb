# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR (UPDATED WITH JUMP DETECTOR) ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        """
        Calculates the Lee-Mykland Statistic for Jump Detection.
        Adapted for Daily Data (using smaller window than hourly).
        """
        # 1. Log Returns
        log_ret = np.log(df / df.shift(1))
        
        # 2. Bipower Variation (Local Volatility Estimate)
        # BV = (pi/2) * rolling_mean( |r_t| * |r_{t-1}| )
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        
        # 3. L-Statistic
        # Avoid division by zero with small epsilon
        l_stat = log_ret / (local_vol + 1e-9)
        
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        
        # 1. Base Returns
        df['returns'] = df[target].pct_change()
        
        # --- NEW: JUMP DETECTION FEATURES ---
        # We add the L-Statistic to the features so agents can learn from it
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        # ------------------------------------
        
        # 2. Trend (ADX & Directional Indicators)
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        
        df['tr'] = np.maximum(high - low, 
                   np.maximum(abs(high - close.shift(1)), 
                              abs(low - close.shift(1))))
        
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), 
                                 np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), 
                                  np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # 3. Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # 4. Crisis / Macro
        if '^VIX' in df.columns:
            df['vix_norm'] = (df['^VIX'] - 15) / 40
        else:
            df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # 5. Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT (UPDATED OBSERVATION SPACE) ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'mean_rev':
            reward = (act * ret * 100) - (0.05 * abs(act))
            
        elif self.mode == 'crisis':
            # Logic: Reward Shorting or Safety during Crash
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: 
                reward *= 2.0 
            elif ret < -0.01 and act > 0.1: 
                reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER (UPDATED REGIME LOGIC WITH JUMPS) ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Mean Rev
        env_mr = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='mean_rev')]) 
        env_mr = VecNormalize(env_mr, norm_obs=True, norm_reward=False)
        model_mr = PPO("MlpPolicy", env_mr, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_mr.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['mean_rev'] = model_mr
        self.envs['mean_rev'] = env_mr
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        # Evaluation Stats
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'mean_rev': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        
        # NEW: L-Statistic Index
        idx_l_stat = cols.index('l_stat')
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'mean_rev': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<10} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            # --- REGIME LOGIC ---
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            
            # NEW: Jump Detection
            l_stat = data_vals[t-1, idx_l_stat]
            
            # Thresholds for Daily Data (Relaxed slightly from 4.0 due to lower freq)
            is_bullish_jump = (l_stat > 3.5)
            is_bearish_jump = (l_stat < -3.5)
            
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > self.config['ADX_THRESHOLD']) and (di_plus > di_minus)
            is_bear_trend = (adx > self.config['ADX_THRESHOLD']) and (di_minus > di_plus)
            
            # PRIORITY LOGIC:
            # 1. Bearish Jump (Immediate Panic) -> CRISIS/BEAR
            # 2. Bullish Jump (Immediate Breakout) -> TREND
            # 3. Standard Logic
            
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "CHOP", "mean_rev"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE ---
            if self.config['LONG_ONLY']:
                if regime in ['BEAR_TREND', 'JUMP_BEAR']:
                    # Strict safety on confirmed downtrends or negative shocks
                    scaled_action = 0.0
                elif regime == 'CRISIS':
                    # Allow trading in panic (bottom fishing) but not sustained bear
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            # Trend Filter
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<10} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['mean_rev'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret

    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'mean_rev'), color='orange', alpha=0.15, label='Chop Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Mean Rev Agent', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # Grid Search Space
        param_grid = {
            "WINDOW_SIZE": [20, 60],
            "ADX_THRESHOLD": [20, 25],
            "TARGET_VOL": [0.20, 0.40] 
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            print(f"Testing Config {i+1}/{len(combinations)}: {params}")
            
            # Create Config Copy
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            # We use the last 1 year of 'Training' data as Validation for optimization
            # In a real scenario, you'd split Train/Val properly.
            # Here we just run a quick backtest on the TRAIN period to see fit.
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            # Fast Training
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            print(f"  -> Return: {ret:.2%}")
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TARGET_VOL'] = 0.40
        config['ADX_THRESHOLD'] = 25
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

            # if optimize:
    # Run optimization on the period PRIOR to the test start
    opt = HyperparameterOptimizer(tickers, target)
    # Use 2020-2023 as optimization/validation window
    best_params = opt.optimize("2016-01-01", start) 
    config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V3 (JUMP DETECTOR ENABLED) <<<")
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT (REPLACED MEAN REV WITH ACCUMULATION) ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': # REPLACED MEAN_REV
            # OBJECTIVE: Maximize exposure to drift, Minimize Jitter (Fees)
            
            # 1. Base Profit
            reward = (act * ret * 100) 
            
            # 2. Accumulation Bias: Reward holding > 50% exposure
            # This teaches the agent that "Chop" in training data is generally up-drift
            if act > 0.5:
                reward += 0.05 * act
            
            # 3. Penalty for Shorting in Accumulation Mode
            # Unless the return is violently negative, shorting chop is bad
            if act < 0:
                reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation (Formerly Mean Rev)
        # We train this on the same trend data, but with the new "Accumulation" reward function
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}, # Renamed
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            is_bullish_jump = (l_stat > 3.5)
            is_bearish_jump = (l_stat < -3.5)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > self.config['ADX_THRESHOLD']) and (di_plus > di_minus)
            is_bear_trend = (adx > self.config['ADX_THRESHOLD']) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation" # Changed from CHOP/mean_rev
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            # 1. JUMP MOMENTUM
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            # 2. Trend Alignment
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            # 3. Accumulation Stability Logic
            if active_agent_name == 'accumulation':
                # If we are in Accumulation (Chop), and above SMA200 (Bull Market),
                # We enforce a "Hold" bias to prevent fee bleed from jitter.
                if sma_dist > 0:
                    # If Agent says Long, we pin to 1.0 to capture full drift
                    if raw_action > 0.2: 
                        raw_action = 1.0
                    # If Agent says Neutral/Short, we force a "Core Hold" of 0.5
                    # unless it's a deep sell (-0.8)
                    elif raw_action > -0.5:
                        raw_action = 0.5
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE ---
            if self.config['LONG_ONLY']:
                if regime in ['BEAR_TREND', 'JUMP_BEAR']:
                    scaled_action = 0.0
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            # Trend Filter
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret

    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # Grid Search Space
        param_grid = {
            "WINDOW_SIZE": [20, 60],
            "ADX_THRESHOLD": [20, 25],
            "TARGET_VOL": [0.20, 0.40] 
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            print(f"Testing Config {i+1}/{len(combinations)}: {params}")
            
            # Create Config Copy
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            # We use the last 1 year of 'Training' data as Validation for optimization
            # In a real scenario, you'd split Train/Val properly.
            # Here we just run a quick backtest on the TRAIN period to see fit.
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            # Fast Training
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            print(f"  -> Return: {ret:.2%}")
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TARGET_VOL'] = 0.40
        config['ADX_THRESHOLD'] = 25
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

            # if optimize:
    # Run optimization on the period PRIOR to the test start
    opt = HyperparameterOptimizer(tickers, target)
    # Use 2020-2023 as optimization/validation window
    best_params = opt.optimize("2016-01-01", start) 
    config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V6 (ACCUMULATION MODE) <<<")
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-01-22"
    END = "2025-10-05"

    run_system(MY_TICKERS, MY_TARGET, START, END)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# Testing Config 1/8: {'WINDOW_SIZE': 20, 'ADX_THRESHOLD': 20, 'TARGET_VOL': 0.2}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2016-01-01 to 2024-01-22)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-22 to 2024-01-22)
#   -> Return: 180.54%
# Testing Config 2/8: {'WINDOW_SIZE': 20, 'ADX_THRESHOLD': 20, 'TARGET_VOL': 0.4}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2016-01-01 to 2024-01-22)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-22 to 2024-01-22)
#   -> Return: 207.62%
# Testing Config 3/8: {'WINDOW_SIZE': 20, 'ADX_THRESHOLD': 25, 'TARGET_VOL': 0.2}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2016-01-01 to 2024-01-22)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-22 to 2024-01-22)
#   -> Return: 126.11%
# Testing Config 4/8: {'WINDOW_SIZE': 20, 'ADX_THRESHOLD': 25, 'TARGET_VOL': 0.4}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2016-01-01 to 2024-01-22)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-22 to 2024-01-22)
#   -> Return: 199.53%
# Testing Config 5/8: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'TARGET_VOL': 0.2}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2016-01-01 to 2024-01-22)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-22 to 2024-01-22)
#   -> Return: 170.76%
# Testing Config 6/8: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'TARGET_VOL': 0.4}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2016-01-01 to 2024-01-22)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-22 to 2024-01-22)
#   -> Return: 209.61%
# Testing Config 7/8: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'TARGET_VOL': 0.2}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2016-01-01 to 2024-01-22)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-22 to 2024-01-22)
#   -> Return: 170.55%
# Testing Config 8/8: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'TARGET_VOL': 0.4}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2016-01-01 to 2024-01-22)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-22 to 2024-01-22)
#   -> Return: 211.85%
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'TARGET_VOL': 0.4} (Ret: 211.85%) <<<
#
# >>> INITIALIZING TRINITY V6 (ACCUMULATION MODE) <<<
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-01-22 to 2025-10-05) ===
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2023-01-22 to 2025-10-05)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-05   | TREND        | trend        | 1.00     | 1.00       | 116484     | 116542     |        0 bps
# 2024-03-05   | TREND        | trend        | 1.00     | 1.00       | 144434     | 144506     |        0 bps
# 2024-04-03   | BEAR_TREND   | crisis       | 1.00     | 0.00       | 150219     | 149549     |       50 bps
# 2024-05-01   | TREND        | trend        | 1.00     | 1.00       | 121743     | 139592     |       -5 bps
# 2024-05-30   | TREND        | trend        | 1.00     | 1.00       | 148411     | 185751     |        0 bps
# 2024-06-28   | TREND        | trend        | 1.00     | 1.00       | 165938     | 207688     |        0 bps
# 2024-07-29   | ACCUMULATION | accumulation | 1.00     | 1.00       | 147605     | 187599     |        0 bps
# 2024-08-26   | CRISIS       | crisis       | 1.00     | 1.00       | 159347     | 212597     |        0 bps
# 2024-09-24   | TREND        | trend        | 1.00     | 1.00       | 141344     | 203217     |       -5 bps
# 2024-10-22   | TREND        | trend        | 1.00     | 1.00       | 162284     | 241416     |        0 bps
# 2024-11-19   | ACCUMULATION | accumulation | 1.00     | 1.00       | 161971     | 247166     |        0 bps
# 2024-12-18   | ACCUMULATION | accumulation | 1.00     | 1.00       | 142039     | 216750     |        0 bps
# 2025-01-21   | ACCUMULATION | accumulation | 1.00     | 1.00       | 158160     | 236792     |        0 bps
# 2025-02-19   | CRISIS       | crisis       | 1.00     | 1.00       | 143404     | 234102     |        0 bps
# 2025-03-19   | BEAR_TREND   | crisis       | 1.00     | 0.00       | 131415     | 197617     |     -181 bps
# 2025-04-16   | CRISIS       | crisis       | 1.00     | 1.00       | 128100     | 175706     |        0 bps
# 2025-05-15   | TREND        | trend        | 1.00     | 1.00       | 165296     | 226724     |        0 bps
# 2025-06-13   | TREND        | trend        | 1.00     | 1.00       | 174061     | 238747     |        0 bps
# 2025-07-15   | TREND        | trend        | 1.00     | 1.00       | 209286     | 287062     |        0 bps
# 2025-08-12   | TREND        | trend        | 1.00     | 1.00       | 224562     | 308016     |        0 bps
# 2025-09-10   | BEAR_TREND   | crisis       | 1.00     | 0.00       | 214941     | 298211     |     -385 bps
#
# === FINAL REPORT: 119.52% (Bench: 215.53%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 189    |      81.26% |      60.52% |      20.74%
# accumulation | 86     |     -13.85% |     -13.72% |      -0.13%
# crisis       | 153    |      40.57% |     127.83% |     -87.25%
# -----------------------------------------------------------------

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters (Optimizable)
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, # New Parameter in Config
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS FROM CONFIG ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            if active_agent_name == 'accumulation':
                if sma_dist > 0:
                    if raw_action > 0.2: raw_action = 1.0
                    elif raw_action > -0.5: raw_action = 0.5
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE ---
            if self.config['LONG_ONLY']:
                if regime in ['BEAR_TREND', 'JUMP_BEAR']:
                    scaled_action = 0.0
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret

    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # Expanded Grid with Sensitivity Parameters
        param_grid = {
            "WINDOW_SIZE": [40, 60],
            "ADX_THRESHOLD": [25, 35, 45], # Tuned for High Beta
            "JUMP_THRESHOLD": [3.5, 4.5], # Tuned for Jumps
            # TARGET_VOL removed for single stock optimization
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            print(f"Testing Config {i+1}/{len(combinations)}: {params}")
            
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            # Validation Window
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            # Fast Training
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            print(f"  -> Return: {ret:.2%}")
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        # config['TARGET_VOL'] is ignored here
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        # Optimizing on pre-2024 data
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V7 (OPTIMIZED) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-02-05" # Matching your log start
    END = "2025-09-10"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# Testing Config 1/12: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
# 1 Failed download:
# ['SHY']: SSLError('Failed to perform, curl: (35) TLS connect error: error:00000000:invalid library (0):OPENSSL_internal:invalid library (0). See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
#   -> Return: 185.44%
# Testing Config 2/12: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 232.22%
# Testing Config 3/12: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 230.11%
# Testing Config 4/12: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 213.36%
# Testing Config 5/12: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 216.55%
# Testing Config 6/12: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 221.44%
# Testing Config 7/12: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 227.34%
# Testing Config 8/12: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 222.78%
# Testing Config 9/12: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 203.78%
# Testing Config 10/12: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 213.65%
# Testing Config 11/12: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 223.88%
# Testing Config 12/12: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 225.46%
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5} (Ret: 232.22%) <<<
#
# >>> INITIALIZING TRINITY V7 (OPTIMIZED) <<<
# Config: Window=40, ADX=25, Jump=4.5
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-02-05 to 2025-09-10) ===
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2023-02-05 to 2025-09-10)
# 1 Failed download:
# ['SHY']: SSLError('Failed to perform, curl: (35) TLS connect error: error:00000000:invalid library (0):OPENSSL_internal:invalid library (0). See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-20   | TREND        | trend        | 0.12     | 1.00       | 99476      | 104976     |        0 bps
# 2024-03-19   | CRISIS       | crisis       | 1.00     | 1.00       | 128051     | 135130     |        0 bps
# 2024-04-17   | ACCUMULATION | accumulation | 1.00     | 1.00       | 119214     | 127024     |        0 bps
# 2024-05-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 113069     | 143039     |        0 bps
# 2024-06-13   | TREND        | trend        | 0.62     | 1.00       | 154878     | 195929     |        0 bps
# 2024-07-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 151143     | 194160     |       -5 bps
# 2024-08-12   | CRISIS       | crisis       | 1.00     | 1.00       | 122210     | 164804     |        0 bps
# 2024-09-10   | BEAR_TREND   | crisis       | 1.00     | 0.00       | 121007     | 163413     |     -153 bps
# 2024-10-08   | TREND        | trend        | 0.73     | 1.00       | 133615     | 200905     |        0 bps
# 2024-11-05   | TREND        | trend        | 0.94     | 1.00       | 137136     | 211518     |       -5 bps
# 2024-12-04   | ACCUMULATION | accumulation | 1.00     | 1.00       | 142262     | 219424     |        0 bps
# 2025-01-03   | ACCUMULATION | accumulation | 1.00     | 1.00       | 144341     | 218426     |        0 bps
# 2025-02-04   | CRISIS       | crisis       | 1.00     | 1.00       | 108719     | 179389     |        0 bps
# 2025-03-05   | BEAR_TREND   | crisis       | 1.00     | 0.00       | 111790     | 177348     |     -118 bps
# 2025-04-02   | CRISIS       | crisis       | 1.00     | 1.00       | 113421     | 166961     |        0 bps
# 2025-05-01   | CRISIS       | crisis       | 1.00     | 1.00       | 121728     | 168760     |        0 bps
# 2025-05-30   | TREND        | trend        | 0.86     | 1.00       | 147380     | 204324     |        0 bps
# 2025-06-30   | TREND        | trend        | 0.63     | 1.00       | 172325     | 238906     |        0 bps
# 2025-07-29   | TREND        | trend        | 0.69     | 1.00       | 191434     | 265399     |        0 bps
# 2025-08-26   | BEAR_TREND   | crisis       | 1.00     | 0.00       | 191219     | 274865     |     -109 bps
#
# === FINAL REPORT: 91.22% (Bench: 158.22%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 177    |      66.14% |      55.11% |      11.03%
# accumulation | 84     |     -14.44% |     -14.31% |      -0.13%
# crisis       | 139    |      34.52% |      94.29% |     -59.77%
# -----------------------------------------------------------------

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS FROM CONFIG ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            if active_agent_name == 'accumulation':
                if sma_dist > 0:
                    if raw_action > 0.2: raw_action = 1.0
                    elif raw_action > -0.5: raw_action = 0.5
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE (THE UNLOCK) ---
            if self.config['LONG_ONLY']:
                # 1. Bearish Jump (Instant Crash) -> Stay Safe
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                
                # 2. Bear Trend (Sustained Drop) -> Check Conviction
                elif regime == 'BEAR_TREND':
                    # If Agent strongly wants to BUY (>0.5), it likely sees a V-Bottom. Allow it.
                    if raw_action > 0.5:
                        # Allow partial exposure to catch the bounce
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        # Otherwise, stay safe
                        scaled_action = 0.0
                
                # 3. Crisis (Panic) -> Agent has full control (Bottom Fishing)
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                
                # 4. Normal
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret

    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # Expanded Grid with Sensitivity Parameters
        param_grid = {
            "WINDOW_SIZE": [40, 60],
            "ADX_THRESHOLD": [25, 35, 45], # Tuned for High Beta
            "JUMP_THRESHOLD": [3.5, 4.5, 5.0], # INCREASED RANGE for NVDA
            # TARGET_VOL removed for single stock optimization
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            print(f"Testing Config {i+1}/{len(combinations)}: {params}")
            
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            # Validation Window
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            # Fast Training
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            print(f"  -> Return: {ret:.2%}")
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        # config['TARGET_VOL'] is ignored here
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        # Optimizing on pre-2024 data
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V8 (UNLOCKED) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-02-05" # Matching your log start
    END = "2025-09-10"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# Testing Config 1/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 223.17%
# Testing Config 2/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 233.63%
# Testing Config 3/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 221.57%
# Testing Config 4/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 219.47%
# Testing Config 5/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 233.32%
# Testing Config 6/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 226.62%
# Testing Config 7/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 218.94%
# Testing Config 8/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 215.93%
# Testing Config 9/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 217.65%
# Testing Config 10/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 195.75%
# Testing Config 11/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 230.06%
# Testing Config 12/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 216.54%
# Testing Config 13/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 214.57%
# Testing Config 14/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 211.27%
# Testing Config 15/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 237.66%
# Testing Config 16/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 224.80%
# Testing Config 17/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 212.74%
# Testing Config 18/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2021-12-31 to 2023-12-31)
#   -> Return: 235.51%
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 5.0} (Ret: 237.66%) <<<
#
# >>> INITIALIZING TRINITY V8 (UNLOCKED) <<<
# Config: Window=60, ADX=35, Jump=5.0
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-02-05 to 2025-09-10) ===
# Fetching data for: ['SHY', 'NVDA', '^VIX'] (2023-02-05 to 2025-09-10)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-20   | TREND        | trend        | 1.00     | 1.00       | 104926     | 104976     |        0 bps
# 2024-03-19   | CRISIS       | crisis       | 1.00     | 1.00       | 135066     | 135130     |        0 bps
# 2024-04-17   | ACCUMULATION | accumulation | 1.00     | 1.00       | 126963     | 127024     |        0 bps
# 2024-05-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 142970     | 143039     |        0 bps
# 2024-06-13   | TREND        | trend        | 1.00     | 1.00       | 195836     | 195929     |        0 bps
# 2024-07-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 194068     | 194160     |        0 bps
# 2024-08-12   | CRISIS       | crisis       | 1.00     | 1.00       | 164725     | 164804     |        0 bps
# 2024-09-10   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 163335     | 163413     |        0 bps
# 2024-10-08   | ACCUMULATION | accumulation | 1.00     | 1.00       | 200809     | 200905     |        0 bps
# 2024-11-05   | ACCUMULATION | accumulation | 1.00     | 1.00       | 211417     | 211518     |        0 bps
# 2024-12-04   | ACCUMULATION | accumulation | 1.00     | 1.00       | 219320     | 219424     |        0 bps
# 2025-01-03   | ACCUMULATION | accumulation | 1.00     | 1.00       | 218322     | 218426     |        0 bps
# 2025-02-04   | CRISIS       | crisis       | 1.00     | 1.00       | 164442     | 179389     |        0 bps
# 2025-03-05   | ACCUMULATION | accumulation | 1.00     | 1.00       | 162571     | 177348     |        0 bps
# 2025-04-02   | CRISIS       | crisis       | 1.00     | 1.00       | 163177     | 166961     |        0 bps
# 2025-05-01   | CRISIS       | crisis       | 1.00     | 1.00       | 164936     | 168760     |        0 bps
# 2025-05-30   | TREND        | trend        | 1.00     | 1.00       | 199693     | 204324     |        0 bps
# 2025-06-30   | TREND        | trend        | 1.00     | 1.00       | 233492     | 238906     |        0 bps
# 2025-07-29   | TREND        | trend        | 1.00     | 1.00       | 259384     | 265399     |        0 bps
# 2025-08-26   | ACCUMULATION | accumulation | 1.00     | 1.00       | 268636     | 274865     |        0 bps
#
# === FINAL REPORT: 152.36% (Bench: 158.22%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 144    |      80.27% |      69.07% |      11.19%
# accumulation | 142    |     -13.26% |     -13.26% |       0.00%
# crisis       | 114    |      61.40% |      76.07% |     -14.68%
# -----------------------------------------------------------------

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS FROM CONFIG ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            if active_agent_name == 'accumulation':
                if sma_dist > 0:
                    if raw_action > 0.2: raw_action = 1.0
                    elif raw_action > -0.5: raw_action = 0.5
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE (THE UNLOCK) ---
            if self.config['LONG_ONLY']:
                # 1. Bearish Jump (Instant Crash) -> Stay Safe
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                
                # 2. Bear Trend (Sustained Drop) -> Check Conviction
                elif regime == 'BEAR_TREND':
                    # If Agent strongly wants to BUY (>0.5), it likely sees a V-Bottom. Allow it.
                    if raw_action > 0.5:
                        # Allow partial exposure to catch the bounce
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        # Otherwise, stay safe
                        scaled_action = 0.0
                
                # 3. Crisis (Panic) -> Agent has full control (Bottom Fishing)
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                
                # 4. Normal
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret

    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # Expanded Grid with Sensitivity Parameters
        param_grid = {
            "WINDOW_SIZE": [40, 60],
            "ADX_THRESHOLD": [25, 35, 45], # Tuned for High Beta
            "JUMP_THRESHOLD": [3.5, 4.5, 5.0], # INCREASED RANGE for NVDA
            # TARGET_VOL removed for single stock optimization
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            print(f"Testing Config {i+1}/{len(combinations)}: {params}")
            
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            # Validation Window
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            # Fast Training
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            print(f"  -> Return: {ret:.2%}")
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        # config['TARGET_VOL'] is ignored here
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        # Optimizing on pre-2024 data
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V8 (UNLOCKED) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["GOOG", "^VIX", "SHY"]
    MY_TARGET = "GOOG"
    START = "2024-01-22"
    END = "2025-05-05"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR GOOG <<<
# Testing Config 1/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 25.81%
# Testing Config 2/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 28.84%
# Testing Config 3/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 26.97%
# Testing Config 4/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 37.74%
# Testing Config 5/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 29.58%
# Testing Config 6/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 36.93%
# Testing Config 7/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 60.03%
# Testing Config 8/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 51.58%
# Testing Config 9/18: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 57.50%
# Testing Config 10/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 28.65%
# Testing Config 11/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 40.89%
# Testing Config 12/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 38.65%
# Testing Config 13/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 33.47%
# Testing Config 14/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 38.87%
# Testing Config 15/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 42.49%
# Testing Config 16/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 57.04%
# Testing Config 17/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 45.32%
# Testing Config 18/18: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 5.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   -> Return: 44.25%
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5} (Ret: 60.03%) <<<
#
# >>> INITIALIZING TRINITY V8 (UNLOCKED) <<<
# Config: Window=40, ADX=45, Jump=3.5
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-01-22 to 2025-05-05) ===
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2023-01-22 to 2025-05-05)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-05   | ACCUMULATION | accumulation | 1.00     | 1.00       | 97175      | 97946      |        0 bps
# 2024-03-05   | ACCUMULATION | accumulation | 1.00     | 1.00       | 89699      | 90410      |        0 bps
# 2024-04-03   | TREND        | trend        | 0.55     | 1.00       | 104846     | 105677     |        0 bps
# 2024-05-01   | CRISIS       | crisis       | 0.37     | 1.00       | 111014     | 111894     |        0 bps
# 2024-05-30   | ACCUMULATION | accumulation | 1.00     | 1.00       | 116372     | 117294     |        0 bps
# 2024-06-28   | ACCUMULATION | accumulation | 1.00     | 1.00       | 123123     | 124099     |        0 bps
# 2024-07-29   | ACCUMULATION | accumulation | 1.00     | 1.00       | 118292     | 115783     |        0 bps
# 2024-08-26   | ACCUMULATION | accumulation | 1.00     | 1.00       | 112450     | 113618     |        0 bps
# 2024-09-24   | ACCUMULATION | accumulation | 1.00     | 1.00       | 109721     | 110862     |        0 bps
# 2024-10-22   | ACCUMULATION | accumulation | 1.00     | 1.00       | 111854     | 113016     |        0 bps
# 2024-11-19   | TREND        | trend        | 0.69     | 1.00       | 120409     | 121660     |        0 bps
# 2024-12-18   | CRISIS       | crisis       | 0.34     | 1.00       | 127641     | 128968     |        0 bps
# 2025-01-21   | ACCUMULATION | accumulation | 1.00     | 1.00       | 128913     | 135397     |        0 bps
# 2025-02-19   | ACCUMULATION | accumulation | 1.00     | 1.00       | 120712     | 126919     |        0 bps
# 2025-03-19   | BEAR_TREND   | crisis       | 0.44     | 0.00       | 112638     | 112906     |     -222 bps
# 2025-04-16   | CRISIS       | crisis       | 0.36     | 1.00       | 120805     | 105587     |        0 bps
#
# === FINAL REPORT: 28.81% (Bench: 12.59%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 43     |      -9.42% |     -12.58% |       3.16%
# accumulation | 188    |      17.53% |      17.89% |      -0.36%
# crisis       | 91     |      21.00% |       9.24% |      11.76%
# -----------------------------------------------------------------

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters (Optimizable)
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS FROM CONFIG ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            if active_agent_name == 'accumulation':
                if sma_dist > 0:
                    if raw_action > 0.2: raw_action = 1.0
                    elif raw_action > -0.5: raw_action = 0.5
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE (UNLOCKED) ---
            if self.config['LONG_ONLY']:
                # 1. Bearish Jump (Instant Crash) -> Stay Safe
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                
                # 2. Bear Trend (Sustained Drop) -> Check Conviction
                elif regime == 'BEAR_TREND':
                    if raw_action > 0.5:
                        # Allow partial exposure
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        scaled_action = 0.0
                
                # 3. Crisis -> Full Control
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                
                # 4. Normal
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret
    
    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # --- GRANULAR GRID FOR SENSITIVITY ---
        param_grid = {
            "WINDOW_SIZE": [40, 60],
            # Includes LOW values (15, 20) for Stable Stocks (Paranoid Mode)
            # Includes HIGH values (35, 45) for Growth Stocks (Relaxed Mode)
            "ADX_THRESHOLD": [15, 20, 25, 35, 45], 
            # Includes LOW shocks (2.0) for Stable Stocks
            # Includes HIGH shocks (4.5) for Volatile Stocks
            "JUMP_THRESHOLD": [2.0, 2.5, 3.5, 4.5]
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            print(f"Testing Config {i+1}/{len(combinations)}: {params}")
            
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            # Print minimal output to avoid clutter
            # print(f"  -> Return: {ret:.2%}")
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                print(f"  >>> NEW BEST: {ret:.2%} {params}")
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V9 (GRANULAR OPTIMIZATION) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["GOOG", "^VIX", "SHY"]
    MY_TARGET = "GOOG"
    START = "2024-02-05" 
    END = "2025-05-05"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR GOOG <<<
# Testing Config 1/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 10.33% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Testing Config 2/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 18.59% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.5}
# Testing Config 3/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 4/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 18.81% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5}
# Testing Config 5/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 6/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 19.31% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.5}
# Testing Config 7/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 8/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 22.25% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 4.5}
# Testing Config 9/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 28.92% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0}
# Testing Config 10/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 11/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 30.32% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Testing Config 12/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 34.20% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Testing Config 13/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 14/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 15/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 37.08% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Testing Config 16/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 37.95% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Testing Config 17/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 53.46% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.0}
# Testing Config 18/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 54.21% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5}
# Testing Config 19/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 20/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 21/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 22/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 23/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 24/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 25/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 26/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 27/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 28/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 29/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 30/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 31/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 32/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 33/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 34/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 35/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 36/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 37/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 38/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 60.94% {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5}
# Testing Config 39/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
# Testing Config 40/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2021-12-31 to 2023-12-31)
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5} (Ret: 60.94%) <<<
#
# >>> INITIALIZING TRINITY V9 (GRANULAR OPTIMIZATION) <<<
# Config: Window=60, ADX=45, Jump=2.5
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-02-05 to 2025-05-05) ===
# Fetching data for: ['SHY', '^VIX', 'GOOG'] (2023-02-05 to 2025-05-05)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-20   | ACCUMULATION | accumulation | 1.00     | 1.00       | 99017      | 99066      |        0 bps
# 2024-03-19   | JUMP_BULL    | trend        | 1.00     | 1.00       | 101905     | 103051     |        0 bps
# 2024-04-17   | TREND        | trend        | 0.34     | 1.00       | 108078     | 109294     |        0 bps
# 2024-05-15   | CRISIS       | crisis       | 0.19     | 1.00       | 119789     | 121137     |        0 bps
# 2024-06-13   | ACCUMULATION | accumulation | 1.00     | 1.00       | 121525     | 123270     |        0 bps
# 2024-07-15   | TREND        | trend        | 0.56     | 1.00       | 129398     | 131256     |        0 bps
# 2024-08-12   | BEAR_TREND   | crisis       | 0.17     | 0.00       | 115907     | 114349     |       87 bps
# 2024-09-10   | ACCUMULATION | accumulation | 0.46     | 1.00       | 104957     | 104764     |       -5 bps
# 2024-10-08   | TREND        | trend        | 0.43     | 1.00       | 115935     | 115722     |        0 bps
# 2024-11-05   | ACCUMULATION | accumulation | 1.00     | 1.00       | 119930     | 119709     |        0 bps
# 2024-12-04   | ACCUMULATION | accumulation | 1.00     | 1.00       | 123204     | 122978     |        0 bps
# 2025-01-03   | BEAR_TREND   | crisis       | 0.30     | 0.00       | 133462     | 135031     |     -136 bps
# 2025-02-04   | ACCUMULATION | accumulation | 1.00     | 1.00       | 137484     | 145225     |        0 bps
# 2025-03-05   | BEAR_TREND   | crisis       | 0.22     | 0.00       | 115453     | 122348     |     -138 bps
# 2025-04-02   | BEAR_TREND   | crisis       | 0.33     | 0.00       | 117422     | 111197     |       -4 bps
# 2025-05-01   | CRISIS       | crisis       | 0.28     | 1.00       | 129630     | 113948     |        0 bps
#
# === FINAL REPORT: 32.03% (Bench: 16.06%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 48     |      -4.74% |      -8.06% |       3.32%
# accumulation | 169    |      15.12% |      15.72% |      -0.60%
# crisis       | 95     |      20.41% |       9.09% |      11.31%
# -----------------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 535
#     532 START = "2024-02-05"
#     533 END = "2025-05-05"
# --> 535 run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
#
# Cell In[9], line 527, in run_system(tickers, target, start, end, optimize)
#     525 mgr = EnsembleManager(config)
#     526 mgr.train_specialists()
# --> 527 mgr.run_backtest()
#
# Cell In[9], line 442, in EnsembleManager.run_backtest(self, start_date, end_date, plot_results)
#     439             print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
#     440     print("-" * 65)
# --> 442     self.plot_dashboard(res)
#     444 return total_ret
#
# AttributeError: 'EnsembleManager' object has no attribute 'plot_dashboard'

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters (Optimizable)
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS FROM CONFIG ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            if active_agent_name == 'accumulation':
                if sma_dist > 0:
                    if raw_action > 0.2: raw_action = 1.0
                    elif raw_action > -0.5: raw_action = 0.5
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE (UNLOCKED) ---
            if self.config['LONG_ONLY']:
                # 1. Bearish Jump (Instant Crash) -> Stay Safe
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                
                # 2. Bear Trend (Sustained Drop) -> Check Conviction
                elif regime == 'BEAR_TREND':
                    if raw_action > 0.5:
                        # Allow partial exposure
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        scaled_action = 0.0
                
                # 3. Crisis -> Full Control
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                
                # 4. Normal
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret
    
    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # --- GRANULAR GRID FOR SENSITIVITY ---
        param_grid = {
            "WINDOW_SIZE": [40, 60],
            # Includes LOW values (15, 20) for Stable Stocks (Paranoid Mode)
            # Includes HIGH values (35, 45) for Growth Stocks (Relaxed Mode)
            "ADX_THRESHOLD": [15, 20, 25, 35, 45], 
            # Includes LOW shocks (2.0) for Stable Stocks
            # Includes HIGH shocks (4.5) for Volatile Stocks
            "JUMP_THRESHOLD": [2.0, 2.5, 3.5, 4.5]
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            print(f"Testing Config {i+1}/{len(combinations)}: {params}")
            
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            # Print minimal output to avoid clutter
            # print(f"  -> Return: {ret:.2%}")
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                print(f"  >>> NEW BEST: {ret:.2%} {params}")
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V9 (GRANULAR OPTIMIZATION) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-02-05" 
    END = "2025-05-05"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# Testing Config 1/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 223.39% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Testing Config 2/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 3/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 4/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 5/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 6/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 7/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 8/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 9/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 10/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 236.83% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.5}
# Testing Config 11/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 12/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 13/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 237.38% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.0}
# Testing Config 14/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 15/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 16/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 17/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 18/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 19/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 20/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 21/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 22/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 23/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 24/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 25/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 26/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 27/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 28/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 29/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 30/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 31/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 32/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 33/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 34/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 35/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 36/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 37/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 38/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 39/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 40/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.0} (Ret: 237.38%) <<<
#
# >>> INITIALIZING TRINITY V9 (GRANULAR OPTIMIZATION) <<<
# Config: Window=40, ADX=35, Jump=2.0
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-02-05 to 2025-05-05) ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2023-02-05 to 2025-05-05)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-20   | TREND        | trend        | 1.00     | 1.00       | 104926     | 104976     |        0 bps
# 2024-03-19   | CRISIS       | crisis       | 1.00     | 1.00       | 135066     | 135130     |        0 bps
# 2024-04-17   | ACCUMULATION | accumulation | 1.00     | 1.00       | 126963     | 127024     |        0 bps
# 2024-05-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 136870     | 143039     |        0 bps
# 2024-06-13   | TREND        | trend        | 1.00     | 1.00       | 187480     | 195929     |        0 bps
# 2024-07-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 173856     | 194160     |        0 bps
# 2024-08-12   | CRISIS       | crisis       | 1.00     | 1.00       | 132834     | 164804     |        0 bps
# 2024-09-10   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 133800     | 163413     |        0 bps
# 2024-10-08   | ACCUMULATION | accumulation | 1.00     | 1.00       | 164497     | 200905     |        0 bps
# 2024-11-05   | ACCUMULATION | accumulation | 1.00     | 1.00       | 164328     | 211518     |        0 bps
# 2024-12-04   | ACCUMULATION | accumulation | 1.00     | 1.00       | 170470     | 219424     |        0 bps
# 2025-01-03   | ACCUMULATION | accumulation | 1.00     | 1.00       | 169695     | 218426     |        0 bps
# 2025-02-04   | CRISIS       | crisis       | 1.00     | 1.00       | 127713     | 179389     |        0 bps
# 2025-03-05   | ACCUMULATION | accumulation | 1.00     | 1.00       | 119175     | 177348     |       -5 bps
# 2025-04-02   | CRISIS       | crisis       | 1.00     | 1.00       | 119619     | 166961     |        0 bps
# 2025-05-01   | CRISIS       | crisis       | 1.00     | 1.00       | 133715     | 168760     |        0 bps
#
# === FINAL REPORT: 37.18% (Bench: 73.13%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 85     |      18.26% |       4.57% |      13.69%
# accumulation | 117    |     -41.13% |     -40.92% |      -0.21%
# crisis       | 110    |      97.02% |     180.22% |     -83.20%
# -----------------------------------------------------------------

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters (Optimizable)
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # NEW: SMA50 for "Smart Accumulation"
        sma50 = df[target].rolling(50).mean()
        df['dist_sma50'] = (df[target] - sma50) / sma50
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        idx_sma50 = cols.index('dist_sma50') # NEW
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            sma50_dist = data_vals[t-1, idx_sma50] # NEW
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS FROM CONFIG ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            # --- SMART ACCUMULATION (V10) ---
            if active_agent_name == 'accumulation':
                # Original: If above SMA200 -> Hold
                # New: Must ALSO be above SMA50 to Hold
                if sma_dist > 0:
                    if sma50_dist > 0:
                        # Healthy Drift (Above SMA200 AND SMA50)
                        if raw_action > 0.2: raw_action = 1.0
                        elif raw_action > -0.5: raw_action = 0.5
                    else:
                        # Weakness (Above SMA200 but Below SMA50) -> The "Slow Bleed"
                        # Force exit to avoid distribution trap
                        raw_action = 0.0 
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE ---
            if self.config['LONG_ONLY']:
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                elif regime == 'BEAR_TREND':
                    if raw_action > 0.5:
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        scaled_action = 0.0
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret

    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # --- GRANULAR GRID FOR SENSITIVITY ---
        param_grid = {
            "WINDOW_SIZE": [40, 60],
            "ADX_THRESHOLD": [15, 20, 25, 35, 45], 
            "JUMP_THRESHOLD": [2.0, 2.5, 3.5, 4.5]
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            print(f"Testing Config {i+1}/{len(combinations)}: {params}")
            
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            # Print minimal output to avoid clutter
            # print(f"  -> Return: {ret:.2%}")
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                print(f"  >>> NEW BEST: {ret:.2%} {params}")
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V10 (SMART ACCUMULATION) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-02-05" 
    END = "2025-05-05"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# Testing Config 1/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 200.77% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Testing Config 2/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 207.90% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.5}
# Testing Config 3/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 212.14% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 3.5}
# Testing Config 4/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 5/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 6/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 7/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 8/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 9/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 227.41% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0}
# Testing Config 10/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 11/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 12/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 13/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 14/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 15/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 16/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 17/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 18/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 19/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 20/40: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 21/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 22/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 23/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 24/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 25/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 26/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 27/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 28/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 29/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 30/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 31/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 32/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 33/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 34/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 35/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 36/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 35, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 37/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.0}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 38/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 2.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 39/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 3.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Testing Config 40/40: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 45, 'JUMP_THRESHOLD': 4.5}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0} (Ret: 227.41%) <<<
#
# >>> INITIALIZING TRINITY V10 (SMART ACCUMULATION) <<<
# Config: Window=40, ADX=25, Jump=2.0
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-02-05 to 2025-05-05) ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2023-02-05 to 2025-05-05)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-20   | TREND        | trend        | 0.90     | 1.00       | 104926     | 104976     |        0 bps
# 2024-03-19   | CRISIS       | crisis       | 1.00     | 1.00       | 135066     | 135130     |        0 bps
# 2024-04-17   | ACCUMULATION | accumulation | 1.00     | 1.00       | 126963     | 127024     |        0 bps
# 2024-05-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 136870     | 143039     |        0 bps
# 2024-06-13   | TREND        | trend        | 1.00     | 1.00       | 187480     | 195929     |        0 bps
# 2024-07-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 173856     | 194160     |        0 bps
# 2024-08-12   | CRISIS       | crisis       | 1.00     | 1.00       | 133650     | 164804     |        0 bps
# 2024-09-10   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 134621     | 163413     |        0 bps
# 2024-10-08   | TREND        | trend        | 1.00     | 1.00       | 165508     | 200905     |        0 bps
# 2024-11-05   | TREND        | trend        | 1.00     | 1.00       | 165337     | 211518     |        0 bps
# 2024-12-04   | ACCUMULATION | accumulation | 1.00     | 1.00       | 171517     | 219424     |        0 bps
# 2025-01-03   | ACCUMULATION | accumulation | 0.00     | 0.00       | 150338     | 218426     |     -445 bps
# 2025-02-04   | CRISIS       | crisis       | 1.00     | 1.00       | 109033     | 179389     |        0 bps
# 2025-03-05   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 101743     | 177348     |       -5 bps
# 2025-04-02   | CRISIS       | crisis       | 1.00     | 1.00       | 102122     | 166961     |        0 bps
# 2025-05-01   | CRISIS       | crisis       | 1.00     | 1.00       | 114156     | 168760     |        0 bps
#
# === FINAL REPORT: 17.11% (Bench: 73.13%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 111    |       8.40% |      -4.15% |      12.55%
# accumulation | 74     |     -35.48% |     -24.38% |     -11.09%
# crisis       | 127    |      67.43% |     138.86% |     -71.43%
# -----------------------------------------------------------------

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters (Optimizable)
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "ACCUM_SMA_WINDOW": 50, # NEW: Optimizable Safety Line
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # --- DYNAMIC SMA GENERATION ---
        # We generate multiple SMAs so the Manager can pick the one from config
        # This is a bit inefficient but robust for optimization
        df['dist_sma50'] = (df[target] - df[target].rolling(50).mean()) / df[target].rolling(50).mean()
        df['dist_sma100'] = (df[target] - df[target].rolling(100).mean()) / df[target].rolling(100).mean()
        df['dist_sma150'] = (df[target] - df[target].rolling(150).mean()) / df[target].rolling(150).mean()
        df['dist_sma200'] = (df[target] - df[target].rolling(200).mean()) / df[target].rolling(200).mean()
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        # --- SELECT DYNAMIC SMA FROM CONFIG ---
        safety_window = self.config['ACCUM_SMA_WINDOW']
        sma_col_name = f'dist_sma{safety_window}'
        idx_safety_sma = cols.index(sma_col_name) if sma_col_name in cols else idx_sma
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            safety_sma_dist = data_vals[t-1, idx_safety_sma] # NEW: Configurable Safety Line
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            # --- SMART ACCUMULATION (ADAPTIVE FILTER) ---
            if active_agent_name == 'accumulation':
                # Use the OPTIMIZED safety window (e.g., SMA50 for GOOG, SMA150 for NVDA)
                if sma_dist > 0:
                    if safety_sma_dist > 0:
                        # Healthy Drift (Above Safety Line)
                        if raw_action > 0.2: raw_action = 1.0
                        elif raw_action > -0.5: raw_action = 0.5
                    else:
                        # Broken Momentum (Below Safety Line)
                        raw_action = 0.0 
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE ---
            if self.config['LONG_ONLY']:
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                elif regime == 'BEAR_TREND':
                    if raw_action > 0.5:
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        scaled_action = 0.0
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret
    
    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        
        # --- EXPANDED GRID FOR ADAPTIVE FILTERS ---
        param_grid = {
            "WINDOW_SIZE": [40, 60],
            "ADX_THRESHOLD": [15, 20, 25, 35, 45], 
            "JUMP_THRESHOLD": [2.0, 2.5, 3.5, 4.5],
            # NEW: ACCUMULATION SMA SAFETY LINE
            # 50 = Tight (Good for GOOG/Low Vol)
            # 150/200 = Loose (Good for NVDA/High Vol)
            "ACCUM_SMA_WINDOW": [50, 100, 150, 200] 
        }
        
        best_ret = -np.inf
        best_config = None
        
        keys, values = zip(*param_grid.items())
        combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
        
        for i, params in enumerate(combinations):
            # print(f"Testing Config {i+1}/{len(combinations)}: {params}") # Reduced verbosity
            
            trial_config = DEFAULT_CONFIG.copy()
            trial_config.update(params)
            trial_config['TICKERS'] = self.tickers
            trial_config['TARGET_ASSET'] = self.target
            trial_config['TRAIN_START'] = train_start
            trial_config['TRAIN_END'] = train_end
            
            trial_config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
            trial_config['TEST_END'] = train_end
            
            trial_config['TRAINING_STEPS'] = 10000 
            
            mgr = EnsembleManager(trial_config)
            mgr.train_specialists(verbose=False)
            ret = mgr.run_backtest(plot_results=False)
            
            if ret > best_ret:
                best_ret = ret
                best_config = params
                print(f"  >>> NEW BEST: {ret:.2%} {params}")
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V11 (ADAPTIVE FILTER) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}, AccumSMA={config['ACCUM_SMA_WINDOW']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-02-05" 
    END = "2025-05-05"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 183.89% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 200.85% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 100}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 218.44% {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 150}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 588
#     585 START = "2024-02-05"
#     586 END = "2025-05-05"
# --> 588 run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
#
# Cell In[6], line 572, in run_system(tickers, target, start, end, optimize)
#     570 if optimize:
#     571     opt = HyperparameterOptimizer(tickers, target)
# --> 572     best_params = opt.optimize("2015-01-01", "2023-12-31")
#     573     config.update(best_params)
#     575 print("\n>>> INITIALIZING TRINITY V11 (ADAPTIVE FILTER) <<<")
#
# Cell In[6], line 544, in HyperparameterOptimizer.optimize(self, train_start, train_end)
#     541 trial_config['TRAINING_STEPS'] = 10000
#     543 mgr = EnsembleManager(trial_config)
# --> 544 mgr.train_specialists(verbose=False)
#     545 ret = mgr.run_backtest(plot_results=False)
#     547 if ret > best_ret:
#
# Cell In[6], line 230, in EnsembleManager.train_specialists(self, verbose)
#     228 env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
#     229 model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
# --> 230 model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
#     231 self.agents['trend'] = model_trend
#     232 self.envs['trend'] = env_trend
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:337, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     334         assert self.ep_info_buffer is not None
#     335         self.dump_logs(iteration)
# --> 337     self.train()
#     339 callback.on_training_end()
#     341 return self
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:278, in PPO.train(self)
#     276     # Clip grad norm
#     277     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 278     self.policy.optimizer.step()
#     280 self._n_updates += 1
#     281 if not continue_training:
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/adam.py:244, in Adam.step(self, closure)
#     232     beta1, beta2 = group["betas"]
#     234     has_complex = self._init_group(
#     235         group,
#     236         params_with_grad,
#    (...)    241         state_steps,
#     242     )
# --> 244     adam(
#     245         params_with_grad,
#     246         grads,
#     247         exp_avgs,
#     248         exp_avg_sqs,
#     249         max_exp_avg_sqs,
#     250         state_steps,
#     251         amsgrad=group["amsgrad"],
#     252         has_complex=has_complex,
#     253         beta1=beta1,
#     254         beta2=beta2,
#     255         lr=group["lr"],
#     256         weight_decay=group["weight_decay"],
#     257         eps=group["eps"],
#     258         maximize=group["maximize"],
#     259         foreach=group["foreach"],
#     260         capturable=group["capturable"],
#     261         differentiable=group["differentiable"],
#     262         fused=group["fused"],
#     263         grad_scale=getattr(self, "grad_scale", None),
#     264         found_inf=getattr(self, "found_inf", None),
#     265     )
#     267 return loss
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/adam.py:876, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     873 else:
#     874     func = _single_tensor_adam
# --> 876 func(
#     877     params,
#     878     grads,
#     879     exp_avgs,
#     880     exp_avg_sqs,
#     881     max_exp_avg_sqs,
#     882     state_steps,
#     883     amsgrad=amsgrad,
#     884     has_complex=has_complex,
#     885     beta1=beta1,
#     886     beta2=beta2,
#     887     lr=lr,
#     888     weight_decay=weight_decay,
#     889     eps=eps,
#     890     maximize=maximize,
#     891     capturable=capturable,
#     892     differentiable=differentiable,
#     893     grad_scale=grad_scale,
#     894     found_inf=found_inf,
#     895 )
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/adam.py:400, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     397 if weight_decay != 0:
#     398     grad = grad.add(param, alpha=weight_decay)
# --> 400 if torch.is_complex(param):
#     401     grad = torch.view_as_real(grad)
#     402     exp_avg = torch.view_as_real(exp_avg)
#
# KeyboardInterrupt:

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters (Optimizable)
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "ACCUM_SMA_WINDOW": 50, # NEW: Optimizable Safety Line
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # --- DYNAMIC SMA GENERATION ---
        # We generate multiple SMAs so the Manager can pick the one from config
        # This is a bit inefficient but robust for optimization
        df['dist_sma50'] = (df[target] - df[target].rolling(50).mean()) / df[target].rolling(50).mean()
        df['dist_sma100'] = (df[target] - df[target].rolling(100).mean()) / df[target].rolling(100).mean()
        df['dist_sma150'] = (df[target] - df[target].rolling(150).mean()) / df[target].rolling(150).mean()
        df['dist_sma200'] = (df[target] - df[target].rolling(200).mean()) / df[target].rolling(200).mean()
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        # --- SELECT DYNAMIC SMA FROM CONFIG ---
        safety_window = self.config['ACCUM_SMA_WINDOW']
        sma_col_name = f'dist_sma{safety_window}'
        idx_safety_sma = cols.index(sma_col_name) if sma_col_name in cols else idx_sma
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            safety_sma_dist = data_vals[t-1, idx_safety_sma] # NEW: Configurable Safety Line
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            # --- SMART ACCUMULATION (ADAPTIVE FILTER) ---
            if active_agent_name == 'accumulation':
                # Use the OPTIMIZED safety window (e.g., SMA50 for GOOG, SMA150 for NVDA)
                if sma_dist > 0:
                    if safety_sma_dist > 0:
                        # Healthy Drift (Above Safety Line)
                        if raw_action > 0.2: raw_action = 1.0
                        elif raw_action > -0.5: raw_action = 0.5
                    else:
                        # Broken Momentum (Below Safety Line)
                        raw_action = 0.0 
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE ---
            if self.config['LONG_ONLY']:
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                elif regime == 'BEAR_TREND':
                    if raw_action > 0.5:
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        scaled_action = 0.0
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret
    
    def plot_dashboard(self, res):
        fig, axes = plt.subplots(4, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [3, 2, 2, 2]})
        plt.subplots_adjust(hspace=0.2)
        
        res['Bench_Equity'] = (1 + res['Benchmark']).cumprod() * self.config['INITIAL_BALANCE']
        ax0 = axes[0]
        ax0.plot(res.index, res['Portfolio'], label='Ensemble AI', color='black', linewidth=2)
        ax0.plot(res.index, res['Bench_Equity'], label='Buy & Hold', color='gray', linestyle='--', alpha=0.6)
        ax0.set_title(f"Equity Curve: {self.config['TARGET_ASSET']}", fontweight='bold')
        ax0.set_ylabel("Portfolio Value ($)")
        ax0.grid(True, alpha=0.3)
        
        y_min, y_max = ax0.get_ylim()
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'trend'), color='green', alpha=0.1, label='Trend Regime')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'accumulation'), color='orange', alpha=0.15, label='Accumulation')
        ax0.fill_between(res.index, y_min, y_max, where=(res['Agent'] == 'crisis'), color='red', alpha=0.15, label='Crisis/Bear Regime')
        ax0.legend(loc='upper left', frameon=True)

        ax1 = axes[1]
        strat_peak = res['Portfolio'].cummax()
        strat_dd = (res['Portfolio'] - strat_peak) / strat_peak
        ax1.fill_between(res.index, strat_dd, 0, color='red', alpha=0.3, label='Strategy Drawdown')
        ax1.set_ylabel("Drawdown %")
        ax1.grid(True, alpha=0.3)

        ax2 = axes[2]
        ax2.plot(res.index, res['Trend_PnL'], label='Trend Agent', color='green', linewidth=1.5)
        ax2.plot(res.index, res['MeanRev_PnL'], label='Accumulation', color='orange', linewidth=1.5)
        ax2.plot(res.index, res['Crisis_PnL'], label='Crisis Agent', color='red', linewidth=1.5)
        ax2.set_ylabel("Profit Contrib ($)")
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.3)

        ax3 = axes[3]
        colors = ['forestgreen' if r > 0 else 'firebrick' for r in res['Return']]
        ax3.bar(res.index, res['Scale Act'], color=colors, width=1.5)
        ax3.set_ylabel("Exposure")
        ax3.set_ylim(-0.1, self.config['MAX_LEVERAGE']*1.1)
        ax3.grid(True, alpha=0.3)
        
        plt.show()

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        print(">>> OPTIMIZATION MODE: SMART GRID (Train once per Window, Backtest many) <<<")
        
        # 1. Training Parameters (Requires Retraining PPO)
        training_grid = {
            "WINDOW_SIZE": [40, 60]
        }
        
        # 2. Inference Parameters (Instant Backtest - No Retraining)
        inference_grid = {
            "ADX_THRESHOLD": [15, 20, 25, 35, 45], 
            "JUMP_THRESHOLD": [2.0, 2.5, 3.5, 4.5],
            "ACCUM_SMA_WINDOW": [50, 100, 150, 200] 
        }
        
        best_ret = -np.inf
        best_config = {} # Initialize as empty dict
        
        # Outer Loop: Architecture (Slow)
        for window in training_grid["WINDOW_SIZE"]:
            print(f"\n[Training Phase] Compiling Agents for Window Size: {window}...")
            
            # Setup Base Config
            base_config = DEFAULT_CONFIG.copy()
            base_config['WINDOW_SIZE'] = window
            base_config['TICKERS'] = self.tickers
            base_config['TARGET_ASSET'] = self.target
            base_config['TRAIN_START'] = train_start
            base_config['TRAIN_END'] = train_end
            base_config['TRAINING_STEPS'] = 10000 
            
            # Train Agents ONCE for this Window Size
            # We pass a COPY to ensure base_config isn't polluted by the manager
            mgr = EnsembleManager(base_config.copy())
            mgr.train_specialists(verbose=False)
            
            # Inner Loop: Logic Thresholds (Fast)
            keys, values = zip(*inference_grid.items())
            combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
            
            print(f"[Inference Phase] Testing {len(combinations)} threshold combinations...")
            
            for i, params in enumerate(combinations):
                # Update Manager's Config in-place (No Retraining)
                mgr.config.update(params)
                
                # Set Validation Period (This modifies mgr.config, but not base_config now)
                mgr.config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
                mgr.config['TEST_END'] = train_end
                
                # Run Fast Backtest
                ret = mgr.run_backtest(plot_results=False)
                
                if ret > best_ret:
                    best_ret = ret
                    # BUG FIX: Construct a clean dictionary with ONLY the hyperparameters.
                    # Do NOT copy the full config to avoid carrying over validation dates.
                    best_config = {
                        "WINDOW_SIZE": window,
                        **params
                    }
                    print(f"  >>> NEW BEST: {ret:.2%} | Win:{window} | {params}")
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V11 (ADAPTIVE FILTER) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}, AccumSMA={config['ACCUM_SMA_WINDOW']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-02-05" 
    END = "2025-05-05"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# >>> OPTIMIZATION MODE: SMART GRID (Train once per Window, Backtest many) <<<
#
# [Training Phase] Compiling Agents for Window Size: 40...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# [Inference Phase] Testing 80 threshold combinations...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 193.25% | Win:40 | {'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 194.27% | Win:40 | {'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 211.01% | Win:40 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 212.08% | Win:40 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#
# [Training Phase] Compiling Agents for Window Size: 60...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# [Inference Phase] Testing 80 threshold combinations...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 218.89% | Win:60 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 222.41% | Win:60 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50} (Ret: 222.41%) <<<
#
# >>> INITIALIZING TRINITY V11 (ADAPTIVE FILTER) <<<
# Config: Window=60, ADX=25, Jump=4.5, AccumSMA=50
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-02-05 to 2025-05-05) ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2023-02-05 to 2025-05-05)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-20   | TREND        | trend        | 1.00     | 1.00       | 104926     | 104976     |        0 bps
# 2024-03-19   | CRISIS       | crisis       | 0.67     | 1.00       | 135066     | 135130     |        0 bps
# 2024-04-17   | ACCUMULATION | accumulation | 1.00     | 1.00       | 126963     | 127024     |        0 bps
# 2024-05-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 136870     | 143039     |        0 bps
# 2024-06-13   | TREND        | trend        | 1.00     | 1.00       | 187480     | 195929     |        0 bps
# 2024-07-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 185787     | 194160     |        0 bps
# 2024-08-12   | CRISIS       | crisis       | 1.00     | 1.00       | 161288     | 164804     |        0 bps
# 2024-09-10   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 159927     | 163413     |        0 bps
# 2024-10-08   | TREND        | trend        | 1.00     | 1.00       | 196619     | 200905     |        0 bps
# 2024-11-05   | TREND        | trend        | 1.00     | 1.00       | 207006     | 211518     |        0 bps
# 2024-12-04   | ACCUMULATION | accumulation | 1.00     | 1.00       | 214744     | 219424     |        0 bps
# 2025-01-03   | ACCUMULATION | accumulation | 0.00     | 0.00       | 188227     | 218426     |     -445 bps
# 2025-02-04   | CRISIS       | crisis       | 1.00     | 1.00       | 136621     | 179389     |        0 bps
# 2025-03-05   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 135067     | 177348     |        0 bps
# 2025-04-02   | CRISIS       | crisis       | 1.00     | 1.00       | 135570     | 166961     |        0 bps
# 2025-05-01   | CRISIS       | crisis       | 1.00     | 1.00       | 145499     | 168760     |        0 bps
#
# === FINAL REPORT: 49.27% (Bench: 73.13%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 109    |      30.13% |      14.89% |      15.24%
# accumulation | 79     |     -37.73% |     -25.12% |     -12.60%
# crisis       | 124    |      84.20% |     101.26% |     -17.05%
# -----------------------------------------------------------------

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters (Optimizable)
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "ACCUM_SMA_WINDOW": 50,
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # --- DYNAMIC SMA GENERATION ---
        df['dist_sma50'] = (df[target] - df[target].rolling(50).mean()) / df[target].rolling(50).mean()
        df['dist_sma100'] = (df[target] - df[target].rolling(100).mean()) / df[target].rolling(100).mean()
        df['dist_sma150'] = (df[target] - df[target].rolling(150).mean()) / df[target].rolling(150).mean()
        df['dist_sma200'] = (df[target] - df[target].rolling(200).mean()) / df[target].rolling(200).mean()
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        
        # --- SELECT DYNAMIC SMA FROM CONFIG ---
        safety_window = self.config['ACCUM_SMA_WINDOW']
        sma_col_name = f'dist_sma{safety_window}'
        idx_safety_sma = cols.index(sma_col_name) if sma_col_name in cols else idx_sma
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        # HYSTERESIS STATE (True = Invested, False = Cash)
        is_accum_invested = True 
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            safety_sma_dist = data_vals[t-1, idx_safety_sma]
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            # --- ROBUST ACCUMULATION (V12) ---
            if active_agent_name == 'accumulation':
                if sma_dist > 0:
                    # HYSTERESIS LOGIC:
                    # 1. Enter if Price > SMA + 2%
                    # 2. Exit if Price < SMA - 2%
                    # 3. Otherwise, maintain previous state
                    
                    if safety_sma_dist > 0.02: # +2% buffer
                        is_accum_invested = True
                    elif safety_sma_dist < -0.02: # -2% buffer
                        is_accum_invested = False
                    # Else: Keep is_accum_invested as is
                    
                    if is_accum_invested:
                        if raw_action > 0.2: raw_action = 1.0
                        elif raw_action > -0.5: raw_action = 0.5
                    else:
                        raw_action = 0.0 
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE (V12) ---
            if self.config['LONG_ONLY']:
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                
                elif regime == 'BEAR_TREND':
                    # V12 FIX: REMOVE THE CAP IF CONVICTION IS HIGH
                    if raw_action > 0.8:
                        # Screaming Buy -> Full Size
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler 
                    elif raw_action > 0.5:
                        # Moderate Buy -> Caution Cap (0.5)
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        scaled_action = 0.0
                
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        print(">>> OPTIMIZATION MODE: SMART GRID (Train once per Window, Backtest many) <<<")
        
        # 1. Training Parameters (Requires Retraining PPO)
        training_grid = {
            "WINDOW_SIZE": [40, 60]
        }
        
        # 2. Inference Parameters (Instant Backtest - No Retraining)
        inference_grid = {
            "ADX_THRESHOLD": [15, 20, 25, 35, 45], 
            "JUMP_THRESHOLD": [2.0, 2.5, 3.5, 4.5],
            "ACCUM_SMA_WINDOW": [50, 100, 150, 200] 
        }
        
        best_ret = -np.inf
        best_config = {} # Initialize as empty dict
        
        # Outer Loop: Architecture (Slow)
        for window in training_grid["WINDOW_SIZE"]:
            print(f"\n[Training Phase] Compiling Agents for Window Size: {window}...")
            
            # Setup Base Config
            base_config = DEFAULT_CONFIG.copy()
            base_config['WINDOW_SIZE'] = window
            base_config['TICKERS'] = self.tickers
            base_config['TARGET_ASSET'] = self.target
            base_config['TRAIN_START'] = train_start
            base_config['TRAIN_END'] = train_end
            base_config['TRAINING_STEPS'] = 10000 
            
            # Train Agents ONCE for this Window Size
            # We pass a COPY to ensure base_config isn't polluted by the manager
            mgr = EnsembleManager(base_config.copy())
            mgr.train_specialists(verbose=False)
            
            # Inner Loop: Logic Thresholds (Fast)
            keys, values = zip(*inference_grid.items())
            combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
            
            print(f"[Inference Phase] Testing {len(combinations)} threshold combinations...")
            
            for i, params in enumerate(combinations):
                # Update Manager's Config in-place (No Retraining)
                mgr.config.update(params)
                
                # Set Validation Period (This modifies mgr.config, but not base_config now)
                mgr.config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
                mgr.config['TEST_END'] = train_end
                
                # Run Fast Backtest
                ret = mgr.run_backtest(plot_results=False)
                
                if ret > best_ret:
                    best_ret = ret
                    # BUG FIX: Construct a clean dictionary with ONLY the hyperparameters.
                    # Do NOT copy the full config to avoid carrying over validation dates.
                    best_config = {
                        "WINDOW_SIZE": window,
                        **params
                    }
                    print(f"  >>> NEW BEST: {ret:.2%} | Win:{window} | {params}")
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V12 (ROBUST) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}, AccumSMA={config['ACCUM_SMA_WINDOW']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-02-05" 
    END = "2025-05-05"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# >>> OPTIMIZATION MODE: SMART GRID (Train once per Window, Backtest many) <<<
#
# [Training Phase] Compiling Agents for Window Size: 40...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# [Inference Phase] Testing 80 threshold combinations...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 217.43% | Win:40 | {'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 222.92% | Win:40 | {'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 237.67% | Win:40 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 243.51% | Win:40 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#
# [Training Phase] Compiling Agents for Window Size: 60...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# [Inference Phase] Testing 80 threshold combinations...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 40, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50} (Ret: 243.51%) <<<
#
# >>> INITIALIZING TRINITY V12 (ROBUST) <<<
# Config: Window=40, ADX=25, Jump=4.5, AccumSMA=50
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-02-05 to 2025-05-05) ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2023-02-05 to 2025-05-05)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-20   | TREND        | trend        | 0.89     | 1.00       | 104926     | 104976     |        0 bps
# 2024-03-19   | CRISIS       | crisis       | 0.88     | 1.00       | 135066     | 135130     |        0 bps
# 2024-04-17   | ACCUMULATION | accumulation | 1.00     | 1.00       | 126963     | 127024     |        0 bps
# 2024-05-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 135013     | 143039     |        0 bps
# 2024-06-13   | TREND        | trend        | 1.00     | 1.00       | 184936     | 195929     |        0 bps
# 2024-07-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 183267     | 194160     |        0 bps
# 2024-08-12   | CRISIS       | crisis       | 1.00     | 1.00       | 159100     | 164804     |        0 bps
# 2024-09-10   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 157757     | 163413     |        0 bps
# 2024-10-08   | TREND        | trend        | 1.00     | 1.00       | 193951     | 200905     |        0 bps
# 2024-11-05   | TREND        | trend        | 1.00     | 1.00       | 204197     | 211518     |        0 bps
# 2024-12-04   | ACCUMULATION | accumulation | 1.00     | 1.00       | 211830     | 219424     |        0 bps
# 2025-01-03   | ACCUMULATION | accumulation | 0.00     | 0.00       | 192943     | 218426     |     -445 bps
# 2025-02-04   | CRISIS       | crisis       | 1.00     | 1.00       | 134100     | 179389     |        0 bps
# 2025-03-05   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 132574     | 177348     |        0 bps
# 2025-04-02   | CRISIS       | crisis       | 1.00     | 1.00       | 133068     | 166961     |        0 bps
# 2025-05-01   | CRISIS       | crisis       | 1.00     | 1.00       | 142814     | 168760     |        0 bps
#
# === FINAL REPORT: 46.51% (Bench: 73.13%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 109    |      30.13% |      14.89% |      15.24%
# accumulation | 79     |     -38.85% |     -25.12% |     -13.72%
# crisis       | 124    |      84.11% |     101.26% |     -17.14%
# -----------------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 582
#     579 START = "2024-02-05"
#     580 END = "2025-05-05"
# --> 582 run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
#
# Cell In[11], line 574, in run_system(tickers, target, start, end, optimize)
#     572 mgr = EnsembleManager(config)
#     573 mgr.train_specialists()
# --> 574 mgr.run_backtest()
#
# Cell In[11], line 472, in EnsembleManager.run_backtest(self, start_date, end_date, plot_results)
#     469             print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
#     470     print("-" * 65)
# --> 472     self.plot_dashboard(res)
#     474 return total_ret
#
# AttributeError: 'EnsembleManager' object has no attribute 'plot_dashboard'

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import itertools
import warnings

warnings.filterwarnings('ignore')

# --- CONFIGURATION ---
DEFAULT_CONFIG = {
    # Assets
    "TICKERS": ["SPY", "IWM", "^VIX", "SHY"], 
    "TARGET_ASSET": "SPY",
    
    # Dates
    "TRAIN_START": "2015-01-01",
    "TRAIN_END": "2023-12-31",
    "TEST_START": "2024-01-02",
    "TEST_END": "2025-05-05",
    
    # Crisis Training Periods
    "CRISIS_PERIODS": [
        ("2018-10-01", "2019-01-01"), # Volmageddon
        ("2020-01-01", "2020-05-01"), # COVID
        ("2022-01-01", "2022-12-31"), # Bear
    ],
    
    # Hyperparameters (Optimizable)
    "WINDOW_SIZE": 60, 
    "ADX_THRESHOLD": 25,
    "JUMP_THRESHOLD": 3.5, 
    "ACCUM_SMA_WINDOW": 50,
    "TARGET_VOL": 0.40,
    
    # Fixed Params
    "BB_STD": 2.0,
    "LEARNING_RATE": 3e-4,
    "BATCH_SIZE": 64,
    "TRAINING_STEPS": 50000, 
    "INITIAL_BALANCE": 100000,
    "FEES": 0.0005,
    "BORROW_RATE": 0.0002, 
    "ACTION_SCALER": 5.0,
    "MAX_LEVERAGE": 1.0, 
    "USE_VOL_TARGETING": True,
    "SMA_TREND_FILTER": True,
    "LONG_ONLY": False 
}

# --- DATA PROCESSOR ---
class DataProcessor:
    def __init__(self, tickers, config):
        self.tickers = list(set(tickers))
        self.config = config
        
    def download(self, start, end):
        try:
            if self.config['TARGET_ASSET'] not in self.tickers:
                self.tickers.append(self.config['TARGET_ASSET'])
                
            print(f"Fetching data for: {self.tickers} ({start} to {end})")
            data = yf.download(self.tickers, start=start, end=end, progress=False)
            
            if isinstance(data.columns, pd.MultiIndex):
                if 'Close' in data.columns.levels[0]: data = data.xs('Close', level=0, axis=1)
                elif 'Adj Close' in data.columns.levels[0]: data = data.xs('Adj Close', level=0, axis=1)
                elif 'Close' in data.columns.levels[1]: data = data.xs('Close', level=1, axis=1)
            
            if isinstance(data, pd.Series): 
                data = data.to_frame()
                if self.config['TARGET_ASSET'] not in data.columns:
                    data.columns = [self.config['TARGET_ASSET']]
            
            ohlc = yf.download(self.config['TARGET_ASSET'], start=start, end=end, progress=False)
            return data, ohlc
        except Exception as e:
            print(f"Data Download Error: {e}")
            return pd.DataFrame(), pd.DataFrame()

    def calculate_lee_mykland(self, df, window=20):
        log_ret = np.log(df / df.shift(1))
        abs_ret = np.abs(log_ret)
        bv_terms = abs_ret * abs_ret.shift(1)
        local_vol = np.sqrt((np.pi / 2) * bv_terms.rolling(window=window).mean())
        l_stat = log_ret / (local_vol + 1e-9)
        return l_stat.fillna(0)

    def add_features(self, df, ohlc):
        target = self.config['TARGET_ASSET']
        if df.empty or target not in df.columns: return pd.DataFrame()
        
        df = df.copy()
        df['returns'] = df[target].pct_change()
        
        # JUMP DETECTION
        l_stat = self.calculate_lee_mykland(df[target], window=20)
        df['l_stat'] = l_stat
        
        # RSI Calculation (NEW V13)
        delta = df[target].diff()
        gain = (delta.where(delta > 0, 0)).fillna(0)
        loss = (-delta.where(delta < 0, 0)).fillna(0)
        avg_gain = gain.rolling(window=14).mean()
        avg_loss = loss.rolling(window=14).mean()
        rs = avg_gain / avg_loss
        df['rsi'] = 100 - (100 / (1 + rs))
        
        # Trend
        high = ohlc['High']
        low = ohlc['Low']
        close = ohlc['Close']
        df['tr'] = np.maximum(high - low, np.maximum(abs(high - close.shift(1)), abs(low - close.shift(1))))
        df['dm_plus'] = np.where((high - high.shift(1)) > (low.shift(1) - low), np.maximum(high - high.shift(1), 0), 0)
        df['dm_minus'] = np.where((low.shift(1) - low) > (high - high.shift(1)), np.maximum(low.shift(1) - low, 0), 0)
        
        window = 14
        df['tr_s'] = df['tr'].rolling(window).mean()
        df['dp_s'] = df['dm_plus'].rolling(window).mean()
        df['dm_s'] = df['dm_minus'].rolling(window).mean()
        df['di_plus'] = 100 * (df['dp_s'] / df['tr_s'])
        df['di_minus'] = 100 * (df['dm_s'] / df['tr_s'])
        df['dx'] = 100 * abs(df['di_plus'] - df['di_minus']) / (df['di_plus'] + df['di_minus'])
        df['adx'] = df['dx'].rolling(window).mean()
        
        # Mean Reversion
        sma = df[target].rolling(20).mean()
        std = df[target].rolling(20).std()
        df['bb_width'] = (std * 2 * 2) / sma
        df['pct_b'] = (df[target] - (sma - 2*std)) / (4*std)
        
        # Crisis
        if '^VIX' in df.columns: df['vix_norm'] = (df['^VIX'] - 15) / 40
        else: df['vix_norm'] = 0
            
        sma200 = df[target].rolling(200).mean()
        df['dist_sma200'] = (df[target] - sma200) / sma200
        
        # --- DYNAMIC SMA GENERATION ---
        df['dist_sma50'] = (df[target] - df[target].rolling(50).mean()) / df[target].rolling(50).mean()
        df['dist_sma100'] = (df[target] - df[target].rolling(100).mean()) / df[target].rolling(100).mean()
        df['dist_sma150'] = (df[target] - df[target].rolling(150).mean()) / df[target].rolling(150).mean()
        df['dist_sma200'] = (df[target] - df[target].rolling(200).mean()) / df[target].rolling(200).mean()
        
        # Volatility
        df['realized_vol_20d'] = df['returns'].rolling(20).std() * np.sqrt(252)
        df['vol_percentile'] = df['realized_vol_20d'].rolling(252).rank(pct=True)
        
        return df.fillna(0)

    def get_data(self, start, end):
        df, ohlc = self.download(start, end)
        return self.add_features(df, ohlc)

    def get_crisis_data(self):
        dfs = []
        for s, e in self.config['CRISIS_PERIODS']:
            d, o = self.download(s, e)
            dfs.append(self.add_features(d, o))
        return pd.concat(dfs).reset_index(drop=True).fillna(0)

# --- ENVIRONMENT ---
class TradingEnv(gym.Env):
    def __init__(self, df, config, mode='trend'):
        super(TradingEnv, self).__init__()
        self.df = df
        self.config = config
        self.mode = mode 
        self.n_features = df.shape[1]
        self.window = config['WINDOW_SIZE']
        self.current_step = self.window
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window * self.n_features,), dtype=np.float32)
        
        self.data = df.values.astype(np.float32)
        self.cols = df.columns.tolist()
        self.idx_sma = self.cols.index('dist_sma200') if 'dist_sma200' in self.cols else -1
        self.idx_pct_b = self.cols.index('pct_b') if 'pct_b' in self.cols else -1
        
    def reset(self, seed=None, options=None):
        self.current_step = self.window
        return self._get_obs(), {}
    
    def _get_obs(self):
        return self.data[self.current_step-self.window : self.current_step].flatten()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, False, {}
            
        act = np.clip(action[0], -1, 1)
        ret = self.data[self.current_step, 0] 
        
        reward = 0
        if self.mode == 'trend':
            reward = act * ret * 100
            if self.idx_sma != -1:
                sma_dist = self.data[self.current_step, self.idx_sma]
                if sma_dist > 0 and act > 0.1: reward += 0.05 * act 
                elif sma_dist < 0 and act < -0.1: reward += 0.05 * abs(act)
                
        elif self.mode == 'accumulation': 
            reward = (act * ret * 100) 
            if act > 0.5: reward += 0.05 * act
            if act < 0: reward -= 0.1 * abs(act)

        elif self.mode == 'crisis':
            reward = (act * ret * 100)
            if ret < -0.01 and act < -0.1: reward *= 2.0 
            elif ret < -0.01 and act > 0.1: reward -= (act * 10.0) 
            
        self.current_step += 1
        return self._get_obs(), reward, False, False, {}

# --- MANAGER ---
class EnsembleManager:
    def __init__(self, config):
        self.config = config
        self.dp = DataProcessor(config['TICKERS'], config)
        self.agents = {}
        self.envs = {}
        
    def train_specialists(self, verbose=True):
        if verbose: print("\n=== 1. TRAINING SPECIALIST AGENTS ===")
        trend_data = self.dp.get_data(self.config['TRAIN_START'], self.config['TRAIN_END'])
        
        # 1. Trend
        env_trend = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='trend')])
        env_trend = VecNormalize(env_trend, norm_obs=True, norm_reward=False)
        model_trend = PPO("MlpPolicy", env_trend, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_trend.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['trend'] = model_trend
        self.envs['trend'] = env_trend
        
        # 2. Accumulation
        env_acc = DummyVecEnv([lambda: TradingEnv(trend_data, self.config, mode='accumulation')]) 
        env_acc = VecNormalize(env_acc, norm_obs=True, norm_reward=False)
        model_acc = PPO("MlpPolicy", env_acc, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_acc.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['accumulation'] = model_acc
        self.envs['accumulation'] = env_acc
        
        # 3. Crisis
        crash_data = self.dp.get_crisis_data()
        env_crisis = DummyVecEnv([lambda: TradingEnv(crash_data, self.config, mode='crisis')])
        env_crisis = VecNormalize(env_crisis, norm_obs=True, norm_reward=False)
        model_crisis = PPO("MlpPolicy", env_crisis, verbose=0, learning_rate=self.config['LEARNING_RATE'])
        model_crisis.learn(total_timesteps=self.config['TRAINING_STEPS'])
        self.agents['crisis'] = model_crisis
        self.envs['crisis'] = env_crisis
        
        if verbose: print("=== TRAINING COMPLETE ===\n")

    def run_backtest(self, start_date=None, end_date=None, plot_results=True):
        s_date = start_date if start_date else self.config['TEST_START']
        e_date = end_date if end_date else self.config['TEST_END']
        
        if plot_results: print(f"=== 2. RUNNING BACKTEST ({s_date} to {e_date}) ===")
        
        warmup_dt = pd.Timestamp(s_date) - pd.Timedelta(days=365)
        full_data = self.dp.get_data(warmup_dt.strftime('%Y-%m-%d'), e_date)
        if full_data.empty: return 0.0
        
        test_indices = np.where((full_data.index >= s_date) & (full_data.index <= e_date))[0]
        if len(test_indices) == 0: return 0.0

        portfolio = self.config['INITIAL_BALANCE']
        benchmark_equity = self.config['INITIAL_BALANCE'] 
        holdings = 0
        history = []
        
        regime_stats = {
            'trend': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'accumulation': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0},
            'crisis': {'days': 0, 'log_ret': 0.0, 'bench_log_ret': 0.0}
        }
        
        cols = full_data.columns.tolist()
        idx_adx = cols.index('adx')
        idx_sma = cols.index('dist_sma200')
        idx_ret = cols.index('returns')
        idx_vol_pct = cols.index('vol_percentile')
        idx_raw_vol = cols.index('realized_vol_20d')
        idx_di_plus = cols.index('di_plus')
        idx_di_minus = cols.index('di_minus')
        idx_l_stat = cols.index('l_stat')
        idx_pct_b = cols.index('pct_b')
        idx_rsi = cols.index('rsi') # NEW
        
        # --- SELECT DYNAMIC SMA FROM CONFIG ---
        safety_window = self.config['ACCUM_SMA_WINDOW']
        sma_col_name = f'dist_sma{safety_window}'
        idx_safety_sma = cols.index(sma_col_name) if sma_col_name in cols else idx_sma
        
        data_vals = full_data.values
        dates = full_data.index
        window = self.config['WINDOW_SIZE']
        
        agent_pnls = {'trend': 0.0, 'accumulation': 0.0, 'crisis': 0.0}
        
        if plot_results:
            print(f"{'Date':<12} | {'Regime':<12} | {'Active Agent':<12} | {'Raw Act':<8} | {'Scale Act':<10} | {'Portfolio':<10} | {'Bench':<10} | {'Daily Alpha':<11}")
            print("-" * 120)
        
        # HYSTERESIS STATE (True = Invested, False = Cash)
        is_accum_invested = True 
        
        for t in test_indices:
            obs_raw = data_vals[t-window : t].flatten()
            
            vol_pct = data_vals[t-1, idx_vol_pct] 
            raw_vol = data_vals[t-1, idx_raw_vol]
            adx = data_vals[t-1, idx_adx]
            sma_dist = data_vals[t-1, idx_sma]
            safety_sma_dist = data_vals[t-1, idx_safety_sma]
            rsi = data_vals[t-1, idx_rsi] # NEW
            di_plus = data_vals[t-1, idx_di_plus]
            di_minus = data_vals[t-1, idx_di_minus]
            l_stat = data_vals[t-1, idx_l_stat]
            
            # --- DYNAMIC THRESHOLDS ---
            JUMP_THRESH = self.config['JUMP_THRESHOLD']
            ADX_THRESH = self.config['ADX_THRESHOLD']
            
            is_bullish_jump = (l_stat > JUMP_THRESH)
            is_bearish_jump = (l_stat < -JUMP_THRESH)
            is_extreme_vol = (vol_pct > 0.90)
            is_crash = (sma_dist < -0.10)
            is_bull_trend = (adx > ADX_THRESH) and (di_plus > di_minus)
            is_bear_trend = (adx > ADX_THRESH) and (di_minus > di_plus)
            
            # PRIORITY LOGIC
            if is_bearish_jump:
                regime, active_agent_name = "JUMP_BEAR", "crisis"
            elif is_bullish_jump:
                regime, active_agent_name = "JUMP_BULL", "trend"
            elif is_extreme_vol or is_crash: 
                regime, active_agent_name = "CRISIS", "crisis"
            elif is_bear_trend:
                regime, active_agent_name = "BEAR_TREND", "crisis"
            elif is_bull_trend: 
                regime, active_agent_name = "TREND", "trend"
            else:
                regime, active_agent_name = "ACCUMULATION", "accumulation"
                
            # Predict
            agent = self.agents[active_agent_name]
            norm_env = self.envs[active_agent_name]
            obs_norm = norm_env.normalize_obs(obs_raw)
            action, _ = agent.predict(obs_norm, deterministic=True)
            
            # Exec
            mkt_ret = data_vals[t, idx_ret]
            raw_action = action[0]
            
            # --- OVERRIDES ---
            
            if regime == 'JUMP_BULL':
                raw_action = 1.0
            
            if active_agent_name == 'trend' and raw_action < 0:
                raw_action = 0.5 
                
            # --- ACCUMULATION WITH RSI + HYSTERESIS (V13) ---
            if active_agent_name == 'accumulation':
                if sma_dist > 0:
                    # 1. Hysteresis on SMA (Trend Structure)
                    if safety_sma_dist > 0.02: 
                        is_accum_invested = True
                    elif safety_sma_dist < -0.02: 
                        is_accum_invested = False
                    
                    # 2. RSI Check (Momentum Health)
                    # If RSI < 45, the drift is weak/dying -> Stay Safe
                    is_rsi_healthy = (rsi > 45)
                    
                    # Combined Logic:
                    # Must be structurally sound (SMA) AND have momentum (RSI)
                    if is_accum_invested and is_rsi_healthy:
                        if raw_action > 0.2: raw_action = 1.0
                        elif raw_action > -0.5: raw_action = 0.5
                    else:
                        raw_action = 0.0 
            
            # Vol Targeting
            vol_scaler = 1.0
            if self.config['USE_VOL_TARGETING'] and raw_vol > 0.01:
                vol_scaler = self.config['TARGET_VOL'] / raw_vol
            vol_scaler = np.clip(vol_scaler, 0.1, 2.0)
            
            # --- DEFENSIVE OVERRIDE (V12) ---
            if self.config['LONG_ONLY']:
                if regime == 'JUMP_BEAR':
                    scaled_action = 0.0
                
                elif regime == 'BEAR_TREND':
                    # V12 FIX: REMOVE THE CAP IF CONVICTION IS HIGH
                    if raw_action > 0.8:
                        # Screaming Buy -> Full Size
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler 
                    elif raw_action > 0.5:
                        # Moderate Buy -> Caution Cap (0.5)
                        scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler * 0.5 
                    else:
                        scaled_action = 0.0
                
                elif regime == 'CRISIS':
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
                else:
                    scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler
            else:
                scaled_action = raw_action * self.config['ACTION_SCALER'] * vol_scaler

            if self.config['LONG_ONLY']: scaled_action = np.clip(scaled_action, 0, 10)
            
            if self.config['SMA_TREND_FILTER'] and active_agent_name == 'trend':
                if sma_dist < 0: scaled_action = np.clip(scaled_action, -10, 0)
                elif sma_dist > 0: scaled_action = np.clip(scaled_action, 0, 10)
            
            position_size = np.clip(scaled_action, -self.config['MAX_LEVERAGE'], self.config['MAX_LEVERAGE'])
            
            # PnL
            cost = abs(position_size - holdings) * self.config['FEES']
            lev_cost = max(0, abs(position_size)-1) * self.config['BORROW_RATE']
            
            step_pnl_pct = (position_size * mkt_ret) - cost - lev_cost
            step_pnl_dollars = portfolio * step_pnl_pct
            
            portfolio *= (1 + step_pnl_pct)
            benchmark_equity *= (1 + mkt_ret)
            holdings = position_size
            
            agent_pnls[active_agent_name] += step_pnl_dollars
            
            # Stats
            regime_stats[active_agent_name]['days'] += 1
            regime_stats[active_agent_name]['log_ret'] += np.log1p(step_pnl_pct)
            regime_stats[active_agent_name]['bench_log_ret'] += np.log1p(mkt_ret)
            
            alpha_bps = (step_pnl_pct - mkt_ret) * 10000
            
            if plot_results and t % 20 == 0: 
                print(f"{str(dates[t].date()):<12} | {regime:<12} | {active_agent_name:<12} | {raw_action:<8.2f} | {position_size:<10.2f} | {portfolio:<10.0f} | {benchmark_equity:<10.0f} | {alpha_bps:>8.0f} bps")
                
            history.append({
                'Date': dates[t],
                'Portfolio': portfolio,
                'Regime': regime,
                'Agent': active_agent_name,
                'Return': step_pnl_pct,
                'Benchmark': mkt_ret,
                'Scale Act': position_size,
                'Trend_PnL': agent_pnls['trend'],
                'MeanRev_PnL': agent_pnls['accumulation'],
                'Crisis_PnL': agent_pnls['crisis']
            })
            
        res = pd.DataFrame(history).set_index('Date')
        total_ret = (portfolio / self.config['INITIAL_BALANCE']) - 1
        
        if plot_results:
            bench_ret = (1 + res['Benchmark']).cumprod().iloc[-1] - 1
            print(f"\n=== FINAL REPORT: {total_ret:.2%} (Bench: {bench_ret:.2%}) ===")
            
            print("\n=== AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===")
            print(f"{'Agent':<12} | {'Days':<6} | {'Agent Ret':<12} | {'Bench Ret':<12} | {'Alpha':<12}")
            print("-" * 65)
            for agent_name, stats in regime_stats.items():
                if stats['days'] > 0:
                    agent_ret = np.exp(stats['log_ret']) - 1
                    bench_ret = np.exp(stats['bench_log_ret']) - 1
                    alpha = agent_ret - bench_ret
                    print(f"{agent_name:<12} | {stats['days']:<6} | {agent_ret:>11.2%} | {bench_ret:>11.2%} | {alpha:>11.2%}")
                else:
                    print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
            print("-" * 65)
            
            self.plot_dashboard(res)
            
        return total_ret

# --- HYPERPARAMETER OPTIMIZER ---
class HyperparameterOptimizer:
    def __init__(self, tickers, target):
        self.tickers = tickers
        self.target = target
        
    def optimize(self, train_start, train_end):
        print(f"\n>>> STARTING HYPERPARAMETER OPTIMIZATION FOR {self.target} <<<")
        print(">>> OPTIMIZATION MODE: SMART GRID (Train once per Window, Backtest many) <<<")
        
        # 1. Training Parameters (Requires Retraining PPO)
        training_grid = {
            "WINDOW_SIZE": [40, 60]
        }
        
        # 2. Inference Parameters (Instant Backtest - No Retraining)
        inference_grid = {
            "ADX_THRESHOLD": [15, 20, 25, 35, 45], 
            "JUMP_THRESHOLD": [2.0, 2.5, 3.5, 4.5],
            "ACCUM_SMA_WINDOW": [50, 100, 150, 200] 
        }
        
        best_ret = -np.inf
        best_config = {} # Initialize as empty dict
        
        # Outer Loop: Architecture (Slow)
        for window in training_grid["WINDOW_SIZE"]:
            print(f"\n[Training Phase] Compiling Agents for Window Size: {window}...")
            
            # Setup Base Config
            base_config = DEFAULT_CONFIG.copy()
            base_config['WINDOW_SIZE'] = window
            base_config['TICKERS'] = self.tickers
            base_config['TARGET_ASSET'] = self.target
            base_config['TRAIN_START'] = train_start
            base_config['TRAIN_END'] = train_end
            base_config['TRAINING_STEPS'] = 10000 
            
            # Train Agents ONCE for this Window Size
            # We pass a COPY to ensure base_config isn't polluted by the manager
            mgr = EnsembleManager(base_config.copy())
            mgr.train_specialists(verbose=False)
            
            # Inner Loop: Logic Thresholds (Fast)
            keys, values = zip(*inference_grid.items())
            combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
            
            print(f"[Inference Phase] Testing {len(combinations)} threshold combinations...")
            
            for i, params in enumerate(combinations):
                # Update Manager's Config in-place (No Retraining)
                mgr.config.update(params)
                
                # Set Validation Period (This modifies mgr.config, but not base_config now)
                mgr.config['TEST_START'] = str(int(train_end[:4]) - 1) + train_end[4:]
                mgr.config['TEST_END'] = train_end
                
                # Run Fast Backtest
                ret = mgr.run_backtest(plot_results=False)
                
                if ret > best_ret:
                    best_ret = ret
                    # BUG FIX: Construct a clean dictionary with ONLY the hyperparameters.
                    # Do NOT copy the full config to avoid carrying over validation dates.
                    best_config = {
                        "WINDOW_SIZE": window,
                        **params
                    }
                    print(f"  >>> NEW BEST: {ret:.2%} | Win:{window} | {params}")
                
        print(f"\n>>> BEST PARAMETERS FOUND: {best_config} (Ret: {best_ret:.2%}) <<<")
        return best_config

def run_system(tickers, target, start, end, optimize=True):
    config = DEFAULT_CONFIG.copy()
    config['TICKERS'] = tickers
    config['TARGET_ASSET'] = target
    config['TEST_START'] = start
    config['TEST_END'] = end
    
    # Safety Defaults for Single Stock
    if target != "SPY":
        config['LONG_ONLY'] = True
        config['MAX_LEVERAGE'] = 1.0
        config['TRAINING_STEPS'] = 50000 
        config['USE_VOL_TARGETING'] = False 
        config['ACTION_SCALER'] = 10.0 

    if optimize:
        opt = HyperparameterOptimizer(tickers, target)
        best_params = opt.optimize("2015-01-01", "2023-12-31") 
        config.update(best_params)
    
    print("\n>>> INITIALIZING TRINITY V13 (RSI CONFIRMATION) <<<")
    print(f"Config: Window={config['WINDOW_SIZE']}, ADX={config['ADX_THRESHOLD']}, Jump={config['JUMP_THRESHOLD']}, AccumSMA={config['ACCUM_SMA_WINDOW']}")
    
    mgr = EnsembleManager(config)
    mgr.train_specialists()
    mgr.run_backtest()

if __name__ == "__main__":
    MY_TICKERS = ["NVDA", "^VIX", "SHY"]
    MY_TARGET = "NVDA"
    START = "2024-02-05" 
    END = "2025-05-05"

    run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
# Out:
# >>> STARTING HYPERPARAMETER OPTIMIZATION FOR NVDA <<<
# >>> OPTIMIZATION MODE: SMART GRID (Train once per Window, Backtest many) <<<
#
# [Training Phase] Compiling Agents for Window Size: 40...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# [Inference Phase] Testing 80 threshold combinations...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 153.95% | Win:40 | {'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 162.49% | Win:40 | {'ADX_THRESHOLD': 15, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 173.47% | Win:40 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 182.66% | Win:40 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 4.5, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#
# [Training Phase] Compiling Agents for Window Size: 60...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# [Inference Phase] Testing 80 threshold combinations...
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 183.49% | Win:60 | {'ADX_THRESHOLD': 20, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#   >>> NEW BEST: 211.02% | Win:60 | {'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50}
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2021-12-31 to 2023-12-31)
#
# >>> BEST PARAMETERS FOUND: {'WINDOW_SIZE': 60, 'ADX_THRESHOLD': 25, 'JUMP_THRESHOLD': 2.0, 'ACCUM_SMA_WINDOW': 50} (Ret: 211.02%) <<<
#
# >>> INITIALIZING TRINITY V13 (RSI CONFIRMATION) <<<
# Config: Window=60, ADX=25, Jump=2.0, AccumSMA=50
#
# === 1. TRAINING SPECIALIST AGENTS ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2015-01-01 to 2023-12-31)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2018-10-01 to 2019-01-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2020-01-01 to 2020-05-01)
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2022-01-01 to 2022-12-31)
# === TRAINING COMPLETE ===
#
# === 2. RUNNING BACKTEST (2024-02-05 to 2025-05-05) ===
# Fetching data for: ['^VIX', 'NVDA', 'SHY'] (2023-02-05 to 2025-05-05)
# Date         | Regime       | Active Agent | Raw Act  | Scale Act  | Portfolio  | Bench      | Daily Alpha
# ------------------------------------------------------------------------------------------------------------------------
# 2024-02-20   | TREND        | trend        | 1.00     | 1.00       | 104926     | 104976     |        0 bps
# 2024-03-19   | CRISIS       | crisis       | 1.00     | 1.00       | 135066     | 135130     |        0 bps
# 2024-04-17   | ACCUMULATION | accumulation | 0.00     | 0.00       | 127782     | 127024     |      387 bps
# 2024-05-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 151993     | 143039     |        0 bps
# 2024-06-13   | TREND        | trend        | 1.00     | 1.00       | 208194     | 195929     |        0 bps
# 2024-07-15   | ACCUMULATION | accumulation | 1.00     | 1.00       | 193064     | 194160     |        0 bps
# 2024-08-12   | CRISIS       | crisis       | 1.00     | 1.00       | 137772     | 164804     |        0 bps
# 2024-09-10   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 138773     | 163413     |        0 bps
# 2024-10-08   | TREND        | trend        | 1.00     | 1.00       | 170612     | 200905     |        0 bps
# 2024-11-05   | TREND        | trend        | 1.00     | 1.00       | 170435     | 211518     |        0 bps
# 2024-12-04   | ACCUMULATION | accumulation | 0.00     | 0.00       | 166710     | 219424     |     -348 bps
# 2025-01-03   | ACCUMULATION | accumulation | 0.00     | 0.00       | 151770     | 218426     |     -445 bps
# 2025-02-04   | CRISIS       | crisis       | 1.00     | 1.00       | 105399     | 179389     |        0 bps
# 2025-03-05   | BEAR_TREND   | crisis       | 1.00     | 1.00       | 98352      | 177348     |       -5 bps
# 2025-04-02   | CRISIS       | crisis       | 1.00     | 1.00       | 98719      | 166961     |        0 bps
# 2025-05-01   | CRISIS       | crisis       | 1.00     | 1.00       | 110352     | 168760     |        0 bps
#
# === FINAL REPORT: 13.21% (Bench: 73.13%) ===
#
# === AGENT PERFORMANCE BREAKDOWN (vs Benchmark in same period) ===
# Agent        | Days   | Agent Ret    | Bench Ret    | Alpha
# -----------------------------------------------------------------
# trend        | 111    |       8.35% |      -4.15% |      12.49%
# accumulation | 74     |     -37.59% |     -24.38% |     -13.21%
# crisis       | 127    |      67.43% |     138.86% |     -71.43%
# -----------------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 594
#     591 START = "2024-02-05"
#     592 END = "2025-05-05"
# --> 594 run_system(MY_TICKERS, MY_TARGET, START, END, optimize=True)
#
# Cell In[12], line 586, in run_system(tickers, target, start, end, optimize)
#     584 mgr = EnsembleManager(config)
#     585 mgr.train_specialists()
# --> 586 mgr.run_backtest()
#
# Cell In[12], line 484, in EnsembleManager.run_backtest(self, start_date, end_date, plot_results)
#     481             print(f"{agent_name:<12} | {0:<6} | {'N/A':>11} | {'N/A':>11} | {'0.00%':>11}")
#     482     print("-" * 65)
# --> 484     self.plot_dashboard(res)
#     486 return total_ret
#
# AttributeError: 'EnsembleManager' object has no attribute 'plot_dashboard'
